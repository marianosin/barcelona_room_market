# %% [markdown]
# # Developing data structure

# %%
import json
import pandas as pd
import numpy as np
import os

# %%
# Functions needed to cleasing data and extracting structured data from  lists of dictionaries
# Function to keep just numeric values and format them as float
def clean_prices(price):
    # Checking if numers are found in the string
    if any(char.isnumeric() for char in price):
        # Returning the float value of the price

        return float(''.join([char for char in price if char.isnumeric() or char == '.']))
    else:
        return None
# Function to remove weird characters from strings and extra spaces and any \t \n or \r
def clean_string(string: str):
    return string.replace('\n', '').replace('\t', '').replace('\r', '').strip()

# Functions for questioning data
# Question: Room size
def room_size(data):
    item = data['room_info']
    if 'pequeña' in item:
        return 'small'
    elif 'mediana' in item:
        return 'medium'
    elif 'grande' in item:
        return 'large'
    else:
        return None
    
# Question: Furnished
def furnished(data):
    item = data['room_info']
    if 'amueblada' in item:
        return True
    else:
        return False

# Question: Private bathroom
def private_bathroom(data):
    item = data['room_info']
    if 'baño privado' in item:
        return True
    else:
        return False

# Question: Individual or double
def individual_or_double(data):
    item = data['room_info']
    if 'individual' in item:
        return True
    elif 'doble' in item:
        return False
    else:
        # If not specified, we assume it is individual
        return True
    
# Question: Room position
def room_position(data):
    item = data['room_info']
    if ('exterior' in item) or( 'experior adaptado' in item):
        return 'exterior'
    elif ('interior' in item) or ('interior adaptado' in item):
        return 'interior'
    elif 'interior y exterior adaptado' in item:
        return 'to be defined'
    else:
        return None

# Flat info questions
# Rooms available
def rooms_available(data):
    item = data['flat_info']
    if 'hab' in item:
        # Get 'hab' postion and get previous item in list
        return int(item[item.index('hab') - 1])
    else:
        return None
# Flat size
def flat_size(data):
    item = data['flat_info']
    if 'm' in item:
        # Get 'm²' postion and get previous item in list
        return float(item[item.index('m') - 1])
    else:
        return None

# Number of bathrooms
def number_of_bathrooms(data):
    item = data['flat_info']
    if 'baño' in item:
        # Get 'baño' postion and get previous item in list
        return int(item[item.index('baño') - 1])
    elif 'baños' in item:
        # Get 'baños' postion and get previous item in list
        return int(item[item.index('baños') - 1])
    else:
        return None
    
# Elevator available
def elevator(data):
    item = data['flat_info']
    if 'ascensor' in item:
        return True
    else:
        return False

# Pool
def pool(data):
    item = data['flat_info']
    if ('piscina propia' in item )or ('piscina comunitaria' in item):
        #print(item)
        return True
    else:
        return False

# Terrace
def terrace(data):
    item = data['flat_info']
    if 'jardin/terraza' in item:
        return True
    else:
        return False

# Washer machine
def washer_machine(data):
    item = data['flat_info']
    if 'lavadora' in item:
        return True
    else:
        return False

# Dryer machine
def dryer_machine(data):
    item = data['flat_info']
    if 'secadora' in item:
        return True
    else:
        return False
    
# Air conditioning
def air_conditioning(data):
    item = data['flat_info']
    if 'aire acond.' in item:
        return True
    else:
        return False

# Heating
def heating(data):
    item = data['flat_info']
    if 'calefacción' in item:
        return True
    else:
        return False

# Internet
def internet(data):
    item = data['flat_info']
    if ('internet' in item) or ('wifi' in item):
        return True
    else:
        return False

# TV
def tv(data):
    item = data['flat_info']
    if 'tv' in item:
        return True
    else:
        return False

# storage
def storage(data):
    item = data['flat_info']
    if 'trastero' in item:
        return True
    else:
        return False

# Flat condition
def flat_condition(data):
    item = data['flat_info']
    if 'en buen estado' in item:
        return 'good'
    elif 'a estrenar' in item:
        return 'new'
    elif 'reformado' in item:
        return 'refurbished'
    elif 'a reformar' in item:
        return 'to be refurbished'
    else:
        return None
    
# Flat rules

# Pets allowed
def pets_allowed(data):
    item = data['rules']
    if 'se admiten mascotas' in item:
        return True
    elif 'no se admiten mascotas' in item:
        return False
    else:
        return None

# Couples allowed
def couples_allowed(data):
    item = data['rules']
    if 'se admiten parejas' in item:
        return True
    elif 'no se admiten parejas' in item:
        return False
    else:
        return None
    
# Smoking allowed
def smoking_allowed(data):
    item = data['rules']
    if 'se permite fumar' in item:
        return True
    elif 'no se permite fumar' in item:
        return False
    else:
        return None

# %%
files = os.listdir('include/pisocompartido/raw')

# %%
file = files[0]

# %%
with open(f'include/pisocompartido/raw/{file}') as f:
    raw_data = json.load(f)

# %%
# Checking data main structure and first 10 elements
for data in raw_data[:10]:
    print(json.dumps(data, indent=4) + '\n')
# Out:
# {
#     "title": "habitaci\u00f3n en alquiler en raval-santa rosa-safaretjos",
#     "price": "450 \u20ac",
#     "address": "c/ pirineus n\u00fam. 104,                                                                                                                              raval-santa rosa-safaretjos,                                                                                                                             santa coloma de gramenet",
#     "lat": "41.4464 ",
#     "lon": "2.2184794",
#     "description": "alquilo una habitaci\u00f3n individual para una persona preferiblemente chica que sea ordenada y limpia interesadas me pueden contactar",
#     "room_info": [
#         "",
#         "mediana",
#         "",
#         "exterior"
#     ],
#     "flat_info": [
#         "",
#         "1",
#         "hab",
#         "",
#         "1",
#         "ba\u00f1o",
#         "",
#         "32",
#         "m",
#         "",
#         "en buen estado"
#     ],
#     "conditions": [],
#     "rules": [
#         "",
#         "no se aceptan mascotas",
#         "",
#         "no se permiten parejas",
#         "",
#         "no se permite fumar"
#     ]
# }
#
# {
#     "title": "habitaci\u00f3n en alquiler en la creu de barber\u00e0",
#     "price": "300 \u20ac",
#     "address": "c/ reis cat\u00f2lics n\u00fam. 127,                                                                                                                              la creu de barber\u00e0,                                                                                                                             sabadell",
#     "lat": "41.523617 ",
#     "lon": "2.115299",
#     "description": "somos una pareja que vivimos en un piso de tres habitaciones, alquilamos una buscamos persona limpia y ordenada , est\u00e1 todo incluido en el precio, hay wifi, se puede fumar, no se aceptan mascotas , tenemos dos gatos, no hay ascensor.  si quieres ver fotos h\u00e1blame por wsp . 654059748",
#     "room_info": [
#         "",
#         "mediana",
#         "",
#         "exterior"
#     ],
#     "flat_info": [
#         "",
#         "1",
#         "hab",
#         "",
#         "1",
#         "ba\u00f1o",
#         "",
#         "90",
#         "m",
#         "",
#         "en buen estado"
#     ],
#     "conditions": [],
#     "rules": [
#         "",
#         "no se aceptan mascotas",
#         "",
#         "no se permiten parejas",
#         "",
#         "no se permite fumar"
#     ]
# }
#
# {
#     "title": "habitaci\u00f3n en alquiler en ca n''anglada",
#     "price": "400 \u20ac",
#     "address": "c/ sant dami\u00e0 n\u00fam. 268,                                                                                                                              ca n'anglada,                                                                                                                             terrassa",
#     "lat": "41.565895 ",
#     "lon": "2.0301566",
#     "description": "se alquila habitaci\u00f3n nueva a estrenar totalmente amueblada, con cama de 135 y smart tv. luminosa y amplia, situada a 10 minutos de la upc, uoc, uab, vapor universitari de terrassa y la facultad de optica y optometria. rodeada de buenos restaurantes, supermercados y comercios de todo tipo.muy bien comunicada, cerca de estaciones de trenrenfe (vallparadis universitat y terrassa est) y de paradas de bus.la vivienda est\u00e1 totalmente reformada y amueblada lista para entrar a vivir, dispone de lavadora, secadora, nevera, horno, placa de vitrocer\u00e1mica, microondas, batidora, platos, tenedores, cuchillos, vasos, herramientas de cocina, toallas, etc. la cama y todo el mobiliario, es totalmente nuevo a estrenar.los pomos de todas las habitaciones disponen de cerradura y clave privada para poder garantizar la seguridad de todo lo que tengas en tu habitaci\u00f3n.el precio de la habitaci\u00f3n incluye una smart tv y tambi\u00e9n viene incluido el servicio de limpieza de las zonas comunes 2 veces al mes.los gastos de wi-fi, agua, electricidad y gas se dividir\u00e1n proporcionalmente entre todos los inquilinos.",
#     "room_info": [
#         "",
#         "mediana",
#         "",
#         "exterior"
#     ],
#     "flat_info": [
#         "",
#         "1",
#         "hab",
#         "",
#         "1",
#         "ba\u00f1o",
#         "",
#         "60",
#         "m",
#         "",
#         "reformado"
#     ],
#     "conditions": [],
#     "rules": [
#         "",
#         "no se aceptan mascotas",
#         "",
#         "no se permiten parejas",
#         "",
#         "no se permite fumar"
#     ]
# }
#
# {
#     "title": "habitaci\u00f3n en alquiler en poble nou",
#     "price": "450 \u20ac",
#     "address": "c/ doctor esteve n\u00fam. 8,                                                                                                                              poble nou,                                                                                                                             manresa",
#     "lat": "41.7321 ",
#     "lon": "1.82501",
#     "description": "se alquilan habitaciones, son doble de m\u00e1s de 12m2, equipada con cama de 1,60x2,00m, tv de 32 pulgadas, armario y escritorio. el piso tiene un total de 6 habitaciones y 2 ba\u00f1os, cocina, zona de lavander\u00eda y esta nuevo a estranar. gastos incluidos (agua, luz, gas y fibra \u00f3ptica).",
#     "room_info": [
#         "",
#         "mediana",
#         "",
#         "exterior",
#         "",
#         "amueblada"
#     ],
#     "flat_info": [
#         "",
#         "1",
#         "hab",
#         "",
#         "2",
#         "ba\u00f1os",
#         "",
#         "120",
#         "m"
#     ],
#     "conditions": [],
#     "rules": [
#         "",
#         "no se aceptan mascotas",
#         "",
#         "no se permiten parejas",
#         "",
#         "no se permite fumar"
#     ]
# }
#
# {
#     "title": "habitaci\u00f3n en alquiler en sant cosme-la granja",
#     "price": "450 \u20ac",
#     "address": "c/ riu anoia n\u00fam. 23,                                                                                                                              sant cosme-la granja,                                                                                                                             el prat de llobregat",
#     "lat": "41.316055 ",
#     "lon": "2.0830314",
#     "description": "habitaci\u00f3n doble luminosa disponible a partir de 6. mayo, 2024 para 1 chica sola trabaja en el aeropuerto, piso limpio y tranquilo, compartir con 2 compa\u00f1eras super simp\u00e1ticas. contactar\u00e9mos por whatsapp 655979264 si tiene interesa,   muchas gracias!!",
#     "room_info": [
#         "",
#         "mediana",
#         "",
#         "exterior"
#     ],
#     "flat_info": [
#         "",
#         "1",
#         "hab",
#         "",
#         "1",
#         "ba\u00f1o",
#         "",
#         "104",
#         "m",
#         "",
#         "reformado"
#     ],
#     "conditions": [],
#     "rules": [
#         "",
#         "no se aceptan mascotas",
#         "",
#         "no se permiten parejas",
#         "",
#         "no se permite fumar"
#     ]
# }
#
# {
#     "title": "habitaci\u00f3n en alquiler en collblanc",
#     "price": "440 \u20ac",
#     "address": "collblanc,                                                                                                                             l'hospitalet de llobregat",
#     "lat": "41.3734906 ",
#     "lon": "2.1125364",
#     "description": "habitaci\u00f3n amueblada y exterior. cama individual, armario de dos puertas, mesita noche, escritorio y silla",
#     "room_info": [
#         "",
#         "mediana",
#         "",
#         "exterior"
#     ],
#     "flat_info": [
#         "",
#         "1",
#         "hab",
#         "",
#         "2",
#         "ba\u00f1os",
#         "",
#         "8",
#         "m",
#         "",
#         "en buen estado"
#     ],
#     "conditions": [],
#     "rules": [
#         "",
#         "no se aceptan mascotas",
#         "",
#         "no se permiten parejas",
#         "",
#         "no se permite fumar"
#     ]
# }
#
# {
#     "title": "habitaci\u00f3n en alquiler en ciutat cooperativa-mol\u00ed nou",
#     "price": "375 \u20ac",
#     "address": "ciutat cooperativa-mol\u00ed nou,                                                                                                                             sant boi de llobregat",
#     "lat": "41.357357291 ",
#     "lon": "2.031441596",
#     "description": "se alquila habitaci\u00f3n con cama de matrimonio sof\u00e1 mesa 2 sillas armario , con derecho a cocina y ba\u00f1o, el precio es de una persona si son dos el precio seria 500\u20ac esta en la mejor zona de ciudad cooperativa molinou, cerca de comercio mercado hospital.",
#     "room_info": [
#         "",
#         "mediana",
#         "",
#         "exterior"
#     ],
#     "flat_info": [
#         "",
#         "1",
#         "hab",
#         "",
#         "0",
#         "ba\u00f1os",
#         "",
#         "80",
#         "m",
#         "",
#         "en buen estado"
#     ],
#     "conditions": [],
#     "rules": [
#         "",
#         "no se aceptan mascotas",
#         "",
#         "no se permiten parejas",
#         "",
#         "no se permite fumar"
#     ]
# }
#
# {
#     "title": "habitaci\u00f3n en alquiler en poble nou-zona ol\u00edmpica",
#     "price": "300 \u20ac",
#     "address": "poble nou-zona ol\u00edmpica,                                                                                                                             terrassa",
#     "lat": "41.5779149 ",
#     "lon": "2.0011389",
#     "description": "se alquila habitacion individual con salida a lavadero, ba\u00f1o completo y cocina a compartir - entrega inmediata",
#     "room_info": [
#         "",
#         "mediana",
#         "",
#         "exterior"
#     ],
#     "flat_info": [
#         "",
#         "1",
#         "hab",
#         "",
#         "1",
#         "ba\u00f1o",
#         "",
#         "10",
#         "m",
#         "",
#         "en buen estado"
#     ],
#     "conditions": [],
#     "rules": [
#         "",
#         "no se aceptan mascotas",
#         "",
#         "no se permiten parejas",
#         "",
#         "no se permite fumar"
#     ]
# }
#
# {
#     "title": "habitaci\u00f3n individual en pla\u00e7a de mallorca 1",
#     "price": "365 \u20ac",
#     "address": "pza. mallorca n\u00fam. 1,                                                                                                                              ctra. de santpedor-bases de manresa,                                                                                                                             manresa",
#     "lat": "41.73338 ",
#     "lon": "1.8316559",
#     "description": "habitacion muy amplia, escritorio, armario y cama de 105. mucha luz. vistas. compartido piso con dos chicas de 21 a\u00f1os .ambiente muy tranquilo. admiten visitas de amigos/as. comedor amplio. cocina en buen estado.",
#     "room_info": [
#         "",
#         "individual",
#         "",
#         "grande",
#         "",
#         "exterior",
#         "",
#         "amueblada"
#     ],
#     "flat_info": [
#         "",
#         "4",
#         "hab",
#         "",
#         "2",
#         "ba\u00f1os",
#         "",
#         "95",
#         "m",
#         "",
#         "en buen estado",
#         "",
#         "lavadora",
#         "",
#         "ascensor",
#         "",
#         "wifi",
#         "",
#         "tv",
#         "",
#         "tendedero",
#         "",
#         "plancha"
#     ],
#     "conditions": [],
#     "rules": [
#         "",
#         "no se aceptan mascotas",
#         "",
#         "no se permiten parejas",
#         "",
#         "no se permite fumar"
#     ]
# }
#
# {
#     "title": "habitaci\u00f3n individual en carrer de les agudes 134",
#     "price": "320 \u20ac",
#     "address": "c/ agudes n\u00fam. 140,                                                                                                                             ciutat meridiana,                                                                                                                             barcelona capital",
#     "lat": "41.461098 ",
#     "lon": "2.172369",
#     "description": "se busca chica para alquilar habitaci\u00f3n (somos dos chicas) ser\u00eda y responsable, se alquila con derecho a usar el resto del piso por supuesto y con unas normas de convivencia. se piden 2 meses de fianza por adelantado . alquiler: una chica sola 310\u20ac// dos chicas 350\u20ac. la superficie es 3'50 x3.  no se aceptan perros o gatos, tenemos un bich\u00f3n malt\u00e9s que est\u00e1 viejo y es bueno. m\u00e1s info 644748476",
#     "room_info": [
#         "",
#         "individual",
#         "",
#         "mediana",
#         "",
#         "exterior",
#         "",
#         "amueblada"
#     ],
#     "flat_info": [
#         "",
#         "3",
#         "hab",
#         "",
#         "1",
#         "ba\u00f1o",
#         "",
#         "54",
#         "m",
#         "",
#         "en buen estado",
#         "",
#         "lavadora",
#         "",
#         "wifi",
#         "",
#         "tendedero"
#     ],
#     "conditions": [],
#     "rules": [
#         "",
#         "se aceptan mascotas",
#         "",
#         "no se permiten parejas",
#         "",
#         "no se permite fumar"
#     ]
# }

# %%
# Initializing new data structure
clean_data = []

# %%
# Removing '' and replacing them with None
for data in raw_data:
    for key in data.keys():
        data[key] = None if data[key] == '' else data[key]

# %%
# First formatting: price, cleasing and getting just numeric values
for data in raw_data:
    print(data)
    clean_data.append({
        'title': clean_string(data['title']) if data['title'] else None,
        'price': clean_prices(data['price']) if data['price'] else np.nan,
        'address': clean_string(data['address']) if data['address'] else None,
        'latitude': data['lat'] if data['lat'] else np.nan,
        'longitude': data['lon'] if data['lon'] else np.nan,
        'description': clean_string(data['description']) if data['description'] else None,
        'room_info': [clean_string(info) for info in data['room_info']] if data['room_info'] else None,
        'flat_info': [clean_string(info) for info in data['flat_info']] if data['flat_info'] else None,
        'rules': [clean_string(rule) for rule in data['rules'] ] if data['rules'] else None,
    })
# Out:
# {'title': 'habitación en alquiler en raval-santa rosa-safaretjos', 'price': '450 €', 'address': 'c/ pirineus núm. 104,                                                                                                                              raval-santa rosa-safaretjos,                                                                                                                             santa coloma de gramenet', 'lat': '41.4464 ', 'lon': '2.2184794', 'description': 'alquilo una habitación individual para una persona preferiblemente chica que sea ordenada y limpia interesadas me pueden contactar', 'room_info': ['', 'mediana', '', 'exterior'], 'flat_info': ['', '1', 'hab', '', '1', 'baño', '', '32', 'm', '', 'en buen estado'], 'conditions': [], 'rules': ['', 'no se aceptan mascotas', '', 'no se permiten parejas', '', 'no se permite fumar']}
# {'title': 'habitación en alquiler en la creu de barberà', 'price': '300 €', 'address': 'c/ reis catòlics núm. 127,                                                                                                                              la creu de barberà,                                                                                                                             sabadell', 'lat': '41.523617 ', 'lon': '2.115299', 'description': 'somos una pareja que vivimos en un piso de tres habitaciones, alquilamos una buscamos persona limpia y ordenada , está todo incluido en el precio, hay wifi, se puede fumar, no se aceptan mascotas , tenemos dos gatos, no hay ascensor.  si quieres ver fotos háblame por wsp . 654059748', 'room_info': ['', 'mediana', '', 'exterior'], 'flat_info': ['', '1', 'hab', '', '1', 'baño', '', '90', 'm', '', 'en buen estado'], 'conditions': [], 'rules': ['', 'no se aceptan mascotas', '', 'no se permiten parejas', '', 'no se permite fumar']}
# {'title': "habitación en alquiler en ca n''anglada", 'price': '400 €', 'address': "c/ sant damià núm. 268,                                                                                                                              ca n'anglada,                                                                                                                             terrassa", 'lat': '41.565895 ', 'lon': '2.0301566', 'description': 'se alquila habitación nueva a estrenar totalmente amueblada, con cama de 135 y smart tv. luminosa y amplia, situada a 10 minutos de la upc, uoc, uab, vapor universitari de terrassa y la facultad de optica y optometria. rodeada de buenos restaurantes, supermercados y comercios de todo tipo.muy bien comunicada, cerca de estaciones de trenrenfe (vallparadis universitat y terrassa est) y de paradas de bus.la vivienda está totalmente reformada y amueblada lista para entrar a vivir, dispone de lavadora, secadora, nevera, horno, placa de vitrocerámica, microondas, batidora, platos, tenedores, cuchillos, vasos, herramientas de cocina, toallas, etc. la cama y todo el mobiliario, es totalmente nuevo a estrenar.los pomos de todas las habitaciones disponen de cerradura y clave privada para poder garantizar la seguridad de todo lo que tengas en tu habitación.el precio de la habitación incluye una smart tv y también viene incluido el servicio de limpieza de las zonas comunes 2 veces al mes.los gastos de wi-fi, agua, electricidad y gas se dividirán proporcionalmente entre todos los inquilinos.', 'room_info': ['', 'mediana', '', 'exterior'], 'flat_info': ['', '1', 'hab', '', '1', 'baño', '', '60', 'm', '', 'reformado'], 'conditions': [], 'rules': ['', 'no se aceptan mascotas', '', 'no se permiten parejas', '', 'no se permite fumar']}
# {'title': 'habitación en alquiler en poble nou', 'price': '450 €', 'address': 'c/ doctor esteve núm. 8,                                                                                                                              poble nou,                                                                                                                             manresa', 'lat': '41.7321 ', 'lon': '1.82501', 'description': 'se alquilan habitaciones, son doble de más de 12m2, equipada con cama de 1,60x2,00m, tv de 32 pulgadas, armario y escritorio. el piso tiene un total de 6 habitaciones y 2 baños, cocina, zona de lavandería y esta nuevo a estranar. gastos incluidos (agua, luz, gas y fibra óptica).', 'room_info': ['', 'mediana', '', 'exterior', '', 'amueblada'], 'flat_info': ['', '1', 'hab', '', '2', 'baños', '', '120', 'm'], 'conditions': [], 'rules': ['', 'no se aceptan mascotas', '', 'no se permiten parejas', '', 'no se permite fumar']}
# {'title': 'habitación en alquiler en sant cosme-la granja', 'price': '450 €', 'address': 'c/ riu anoia núm. 23,                                                                                                                              sant cosme-la granja,                                                                                                                             el prat de llobregat', 'lat': '41.316055 ', 'lon': '2.0830314', 'description': 'habitación doble luminosa disponible a partir de 6. mayo, 2024 para 1 chica sola trabaja en el aeropuerto, piso limpio y tranquilo, compartir con 2 compañeras super simpáticas. contactarémos por whatsapp 655979264 si tiene interesa,   muchas gracias!!', 'room_info': ['', 'mediana', '', 'exterior'], 'flat_info': ['', '1', 'hab', '', '1', 'baño', '', '104', 'm', '', 'reformado'], 'conditions': [], 'rules': ['', 'no se aceptan mascotas', '', 'no se permiten parejas', '', 'no se permite fumar']}
# {'title': 'habitación en alquiler en collblanc', 'price': '440 €', 'address': "collblanc,                                                                                                                             l'hospitalet de llobregat", 'lat': '41.3734906 ', 'lon': '2.1125364', 'description': 'habitación amueblada y exterior. cama individual, armario de dos puertas, mesita noche, escritorio y silla', 'room_info': ['', 'mediana', '', 'exterior'], 'flat_info': ['', '1', 'hab', '', '2', 'baños', '', '8', 'm', '', 'en buen estado'], 'conditions': [], 'rules': ['', 'no se aceptan mascotas', '', 'no se permiten parejas', '', 'no se permite fumar']}
# {'title': 'habitación en alquiler en ciutat cooperativa-molí nou', 'price': '375 €', 'address': 'ciutat cooperativa-molí nou,                                                                                                                             sant boi de llobregat', 'lat': '41.357357291 ', 'lon': '2.031441596', 'description': 'se alquila habitación con cama de matrimonio sofá mesa 2 sillas armario , con derecho a cocina y baño, el precio es de una persona si son dos el precio seria 500€ esta en la mejor zona de ciudad cooperativa molinou, cerca de comercio mercado hospital.', 'room_info': ['', 'mediana', '', 'exterior'], 'flat_info': ['', '1', 'hab', '', '0', 'baños', '', '80', 'm', '', 'en buen estado'], 'conditions': [], 'rules': ['', 'no se aceptan mascotas', '', 'no se permiten parejas', '', 'no se permite fumar']}
# {'title': 'habitación en alquiler en poble nou-zona olímpica', 'price': '300 €', 'address': 'poble nou-zona olímpica,                                                                                                                             terrassa', 'lat': '41.5779149 ', 'lon': '2.0011389', 'description': 'se alquila habitacion individual con salida a lavadero, baño completo y cocina a compartir - entrega inmediata', 'room_info': ['', 'mediana', '', 'exterior'], 'flat_info': ['', '1', 'hab', '', '1', 'baño', '', '10', 'm', '', 'en buen estado'], 'conditions': [], 'rules': ['', 'no se aceptan mascotas', '', 'no se permiten parejas', '', 'no se permite fumar']}
# {'title': 'habitación individual en plaça de mallorca 1', 'price': '365 €', 'address': 'pza. mallorca núm. 1,                                                                                                                              ctra. de santpedor-bases de manresa,                                                                                                                             manresa', 'lat': '41.73338 ', 'lon': '1.8316559', 'description': 'habitacion muy amplia, escritorio, armario y cama de 105. mucha luz. vistas. compartido piso con dos chicas de 21 años .ambiente muy tranquilo. admiten visitas de amigos/as. comedor amplio. cocina en buen estado.', 'room_info': ['', 'individual', '', 'grande', '', 'exterior', '', 'amueblada'], 'flat_info': ['', '4', 'hab', '', '2', 'baños', '', '95', 'm', '', 'en buen estado', '', 'lavadora', '', 'ascensor', '', 'wifi', '', 'tv', '', 'tendedero', '', 'plancha'], 'conditions': [], 'rules': ['', 'no se aceptan mascotas', '', 'no se permiten parejas', '', 'no se permite fumar']}
# {'title': 'habitación individual en carrer de les agudes 134', 'price': '320 €', 'address': 'c/ agudes núm. 140,                                                                                                                             ciutat meridiana,                                                                                                                             barcelona capital', 'lat': '41.461098 ', 'lon': '2.172369', 'description': "se busca chica para alquilar habitación (somos dos chicas) sería y responsable, se alquila con derecho a usar el resto del piso por supuesto y con unas normas de convivencia. se piden 2 meses de fianza por adelantado . alquiler: una chica sola 310€// dos chicas 350€. la superficie es 3'50 x3.  no se aceptan perros o gatos, tenemos un bichón maltés que está viejo y es bueno. más info 644748476", 'room_info': ['', 'individual', '', 'mediana', '', 'exterior', '', 'amueblada'], 'flat_info': ['', '3', 'hab', '', '1', 'baño', '', '54', 'm', '', 'en buen estado', '', 'lavadora', '', 'wifi', '', 'tendedero'], 'conditions': [], 'rules': ['', 'se aceptan mascotas', '', 'no se permiten parejas', '', 'no se permite fumar']}
# {'title': 'habitación individual en carrer de còrsega 611', 'price': '550 €', 'address': 'c/ còrsega núm. 611,                                                                                                                             la sagrada família,                                                                                                                             barcelona capital', 'lat': '41.408566 ', 'lon': '2.1751537', 'description': 'piso cómodo, ambiente tranquilo, hay una gatita en la casa. acceso con ascensor, tenemos dos balcones con vista a la sagrada familia, tendero en el balcón. cerca de todos los servicios. precio incluye gastos compartidos luz, agua, gas, internet.habitación individual, para entrar el 1 de marzo, disponible solo para 1 una persona, con ventana a la calle, cama individual, mesita de noche, armario cajonera y escritorio.', 'room_info': ['', 'individual', '', 'mediana', '', 'exterior', '', 'amueblada'], 'flat_info': ['', '4', 'hab', '', '1', 'baño', '', '75', 'm', '', 'en buen estado', '', 'ascensor', '', 'wifi', '', 'balcón'], 'conditions': [], 'rules': ['', 'no se aceptan mascotas', '', 'no se permiten parejas', '', 'no se permite fumar']}
# {'title': 'habitación doble en avinguda meridiana 499', 'price': '725 €', 'address': 'avda. meridiana núm. 499,                                                                                                                             la prosperitat,                                                                                                                             barcelona capital', 'lat': '41.441994 ', 'lon': '2.1857448', 'description': 'hola! soy una chica que trabaja en el sector automoción. busco compañera de piso. el piso está reformado y amueblado. es un triplex totalmente exterior, con mucha luz. tiene 3 habitaciones pero una de ellas la uso como vestidor. a compartir sólo conmigo y mi perrito paco, que se porta muy muy bien. el único requisito que pido es que la chica sea limpia y ordenada. habitación lista para entrar a vivir el 1 de junio. el precio incluye todos los gastos. netflix, movistar +, amazon prime video. además dispongo de una plaza de parking para coche. el barrio es muy tranquilo. cerca del cc la maquinista y de sant andreu. también cerca del cc heron city. fácil acceso al nus de la trinitat, a las rondas, c33, c58, ap7. metro linea 1 torras i bages y linea 4 via júlia. por favor contacto sólo por whatsapp. muchas gracias! 😊', 'room_info': ['', 'doble', '', 'mediana', '', 'exterior', '', 'amueblada'], 'flat_info': ['', '3', 'hab', '', '1', 'baño', '', '85', 'm', '', 'reformado', '', 'lavadora', '', 'ascensor', '', 'wifi', '', 'tv', '', 'balcón', '', 'tendedero', '', 'plancha'], 'conditions': [], 'rules': ['', 'no se aceptan mascotas', '', 'no se permiten parejas', '', 'no se permite fumar']}
# {'title': 'habitación individual en carrer del cep 7', 'price': '800 €', 'address': 'c/ cep núm. 9,                                                                                                                             el congrés-els indians,                                                                                                                             barcelona capital', 'lat': '41.425137 ', 'lon': '2.1821876', 'description': 'habitación doble con aire acondicionado y televisor en apartamento completamente reformado y exterior. el precio es para una persona. se admiten parejas con un suplemento de 200 eur.el apartamento se encuentra a 1 minuto de la estación de metro de ccongrès y a 5 de la sagrera (metro y renfe).', 'room_info': ['', 'individual', '', 'mediana', '', 'exterior', '', 'llave propia'], 'flat_info': ['', '3', 'hab', '', '1', 'baño', '', '77', 'm', '', 'reformado', '', 'lavadora', '', 'ascensor', '', 'wifi', '', 'tv', '', 'plancha', '', 'aire acond.'], 'conditions': [], 'rules': ['', 'no se aceptan mascotas', '', 'no se permiten parejas', '', 'no se permite fumar']}
# {'title': 'habitación doble en carrer de monturiol 1', 'price': '600 €', 'address': 'c/ monturiol núm. 1,                                                                                                                                                                      santa coloma de cervelló, barcelona', 'lat': '41.361206 ', 'lon': '2.0265274', 'description': '“solo genero femenino”casa situada en la mejor zona de santa coloma de cervelló, en la colonia güell (patrimonio cultural). renfe y ferrocarriles catalanes, a 2’ minutos del bus. a 20’ de belvitge, varios supermercados cerca. zona de aparcamiento. persona tranquila, educada, ordenada, respetuosa y sobre todo cuidadosa con las zonas comunes y la limpieza, que no esta incluida. no se aceptan visitas, ni parejas ni hijos. con cama doble, mesita de noche, armario empotrado doble, escritorio y silla, casa  compartida (baño, cocina, comedor, salón, patios interior y exterior), la ventana de la habitación da a  la calle y balcón,  con mesa y silla, ventana grande eléctrica con mando.gastos incluidos, el ambiente de la casa es tranquilo y armonioso.se piden 3 últimas nóminas, se reserva con 300€ que se quitará de la fianza si te quedas, sino lo pierdes, se hará contrato y seguro de impago.valor no negociable.', 'room_info': ['', 'doble', '', 'mediana', '', 'exterior', '', 'amueblada', '', 'llave propia', '', 'balcón propio'], 'flat_info': ['', '2', 'hab', '', '1', 'baño', '', '95', 'm', '', 'en buen estado', '', 'lavadora', '', 'wifi', '', 'tv', '', 'jardín/terraza', '', 'balcón', '', 'tendedero'], 'conditions': [], 'rules': ['', 'no se aceptan mascotas', '', 'no se permiten parejas', '', 'no se permite fumar']}
# {'title': 'habitación doble en passeig sant gervasi 72', 'price': '550 €', 'address': 'pseo sant gervasi núm. 72,                                                                                                                             el putxet-el farró,                                                                                                                             barcelona capital', 'lat': '41.41226 ', 'lon': '2.138215', 'description': 'alquilo una habitación en la zona alta de barcelona, tibidabo en finca regia decó, con ambientes amplios, buenas vistas y tranquilo, ideal para estudiantes de doctorado o trabajadores. el piso tiene 140 metros que lo compartiremos solo dos personas + una terraza comunitaria con excelentes vistas al mar y al montaña (para tomar sol, leer y puntualmente comer).la zona es especialmente residencial y agradable, al lado del parque i la carretera de las aguas i park guell. con muy buenas conexiones de medio de transporte l7 av. tibidabo, l3 vallcarca, h4, v15, v13 etc, nitbus 4-5 (a 10 min del pl. catalunya).', 'room_info': ['', 'doble', '', 'grande', '', 'amueblada', '', 'llave propia'], 'flat_info': ['', '3', 'hab', '', '1', 'baño', '', '120', 'm', '', 'en buen estado', '', 'lavadora', '', 'ascensor', '', 'wifi', '', 'tv', '', 'jardín/terraza', '', 'tendedero', '', 'plancha'], 'conditions': [], 'rules': ['', 'no se aceptan mascotas', '', 'no se permiten parejas', '', 'no se permite fumar']}
# {'title': 'habitación en alquiler en la sagrera', 'price': '400 €', 'address': 'avda. meridiana núm. 341,                                                                                                                             la sagrera,                                                                                                                             barcelona capital', 'lat': '41.426876 ', 'lon': '2.1849902', 'description': 'es un piso con iluminación  , la habitación es con ventana interior al patio y cama de dos plazas más un armario empotrado,  somos personas  tranquilos  y trabajamos y algunas veces compartimos,  se valora mucho la limpieza ,orden ,respeto, y  comunicación para que la convivencia sea más ameno .  la ubicación del piso es muy céntrico y accesible a supermercados y tiendas y trasporte co ml o metro l5, l1 , y trenes y autobuses .', 'room_info': ['', 'mediana', '', 'exterior'], 'flat_info': ['', '1', 'hab', '', '2', 'baños', '', '100', 'm', '', 'reformado'], 'conditions': [], 'rules': ['', 'no se aceptan mascotas', '', 'no se permiten parejas', '', 'no se permite fumar']}
# {'title': 'habitación doble en carrer de blai 67', 'price': '480 €', 'address': 'c/ blai núm. 67,                                                                                                                             el poble-sec,                                                                                                                             barcelona capital', 'lat': '41.374725 ', 'lon': '2.161607', 'description': 'alquilo 3 habitaciones muy bien acondicionadas (todas con armarios y muebles auxiliares incluido mesa para portátil y silla), para vivir solo una chica por habitación y máximo 3 chicas en el piso. una habitación con cama individual no disponible 400 € mes y 2 habitaciones disponibles con cama  matrimonio una interior 480 € mes y otra exterior 490 € mes. a sumar gastos suministros 55 € mes. piso calle blai, 67 esquina avenida paralel y calle calabria, muy bien amueblado, todo tipo enseres y electrodomésticos. internet fibra 300 megas. edificio frente metro parada poble sec (línea 3, verde) conexiones cercanas al resto de líneas y múltiples líneas autobús. ubicación inmejorable cerca centro barcelona, entre plaza españa y puerto, muy cerca de montaña de montjuic donde hay zonas verdes, museos y lugares turísticos, cerca playas y ambulatorio  seguridad social, rodeado de todo tipo comercios y lugares de ocio. solo se puede fumar en el balcón. consultar fechas y resto condiciones a maría', 'room_info': ['', 'doble', '', 'grande', '', 'exterior', '', 'amueblada'], 'flat_info': ['', '3', 'hab', '', '1', 'baño', '', '80', 'm', '', 'reformado', '', 'lavadora', '', 'ascensor', '', 'wifi', '', 'tv', '', 'tendedero', '', 'plancha', '', 'aire acond.'], 'conditions': [], 'rules': ['', 'no se aceptan mascotas', '', 'no se permiten parejas', '', 'no se permite fumar']}
# {'title': 'habitación individual en carrer de santiago rusiñol 45', 'price': '400 €', 'address': 'c/ santiago rusiñol núm. 45,                                                                                                                              centre,                                                                                                                             sant cugat del vallès', 'lat': '41.472786 ', 'lon': '2.0837681', 'description': 'pis amb dues noies estudiants universitàries de girona busquen una altra estudiant universitària. amb habitació individual amb mobles, molt cèntric i connexió fàcil amb la uab i la uic.disposa de calefacció central, cuina completament equipada, i bany complet, terrassa i ampli menjador.', 'room_info': ['', 'individual', '', 'pequeña', '', 'amueblada', '', 'llave propia'], 'flat_info': ['', '3', 'hab', '', '1', 'baño', '', '75', 'm', '', 'en buen estado', '', 'lavadora', '', 'tv', '', 'jardín/terraza', '', 'balcón', '', 'tendedero', '', 'plancha', '', 'aire acond.'], 'conditions': [], 'rules': ['', 'no se aceptan mascotas', '', 'no se permiten parejas', '', 'no se permite fumar']}
# {'title': "habitación doble en carrer d'aragó 606", 'price': '550 €', 'address': 'c/ aragon núm. 606,                                                                                                                             el clot,                                                                                                                             barcelona capital', 'lat': '41.4091316 ', 'lon': '2.1879821', 'description': 'se alquila espacio grande para parejas o personas pensionistas, la habitacion es grande con cama matrimonial y cama individual,balcon espacioso y comedor grande  todo privado., no se aceptan menores de edad ni mascotas.                          ****visitas a partir del  6  mayo  2024*****', 'room_info': ['', 'doble', '', 'grande', '', 'exterior', '', 'amueblada', '', 'llave propia', '', 'balcón propio'], 'flat_info': ['', '3', 'hab', '', '1', 'baño', '', '95', 'm', '', 'en buen estado', '', 'trastero', '', 'lavadora', '', 'ascensor', '', 'wifi', '', 'tv', '', 'balcón', '', 'tendedero', '', 'plancha'], 'conditions': [], 'rules': ['', 'no se aceptan mascotas', '', 'se permiten parejas', '', 'no se permite fumar']}
# {'title': "habitación individual en carrer de l'abat escarré 40", 'price': '375 €', 'address': 'c/ abat escarré núm. 40,                                                                                                                              centre,                                                                                                                             sant boi de llobregat', 'lat': '41.3440917 ', 'lon': '2.0302144', 'description': 'habitación sólo para una chica/mujer.habitación exterior mediana/pequeña, en casa adosada de 200 m2, con terrado y patio con jardín. la habitación se encuentra en la 1a planta. se pueden utilizar todas las estancias comunes de la casa. actualmente están ocupadas dos habitaciones por una mujer (asistente social) y por un hombre (profesor de secundaria). muy cerca de transporte público, entidades sociales, tiendas, gimnasios y espacios verdes para hacer deporte.no se permite fumar en ninguna estancia de la casa.no se permiten mascotas.', 'room_info': ['', 'individual', '', 'pequeña', '', 'exterior', '', 'baño propio', '', 'amueblada'], 'flat_info': ['', '4', 'hab', '', '2', 'baños', '', '200', 'm', '', 'en buen estado', '', 'trastero', '', 'lavadora', '', 'tv', '', 'jardín/terraza', '', 'tendedero', '', 'plancha'], 'conditions': [], 'rules': ['', 'no se aceptan mascotas', '', 'no se permiten parejas', '', 'no se permite fumar']}
# {'title': "habitación doble en carrer d'alfou 4", 'price': '450 €', 'address': 'c/ alfou núm. 4,                                                                                                                                                                      dosrius, barcelona', 'lat': '41.61269 ', 'lon': '2.42027', 'description': 'se alquila habitación doble para una sola persona, en casa unifamiliar, a compartir con una mujer. vivo con gatos. abstenerse personas que no les gusten los animales. casa con jardín y piscina. hay escaleras. en el exterior de la vivienda se puede fumar. gastos incluidos: agua, luz e internet.', 'room_info': ['', 'doble', '', 'mediana', '', 'exterior', '', 'amueblada', '', 'llave propia'], 'flat_info': ['', '2', 'hab', '', '2', 'baños', '', '100', 'm', '', 'en buen estado', '', 'trastero', '', 'lavadora', '', 'piscina propia', '', 'wifi', '', 'tv', '', 'jardín/terraza', '', 'balcón', '', 'tendedero', '', 'plancha', '', 'secadora'], 'conditions': [], 'rules': ['', 'no se aceptan mascotas', '', 'no se permiten parejas', '', 'no se permite fumar']}
# {'title': 'habitación individual en carrer del gaià 2', 'price': '400 €', 'address': 'c/ gaià núm. 2,                                                                                                                             la marina del port-parc de montjuïc,                                                                                                                             barcelona capital', 'lat': '41.362175 ', 'lon': '2.1410086', 'description': 'habitacion en el barrio de la marina del puerto. búsqueda de plaza españa y junto a la montaña de montjuïc y con buena comunicación de transporte público.apartamento con mucha luz natural en todas las habitaciones y una terraza común con vistas al exterior.', 'room_info': ['', 'individual', '', 'mediana', '', 'exterior', '', 'amueblada'], 'flat_info': ['', '3', 'hab', '', '1', 'baño', '', '65', 'm', '', 'reformado', '', 'trastero', '', 'lavadora', '', 'wifi', '', 'jardín/terraza', '', 'balcón', '', 'tendedero'], 'conditions': [], 'rules': ['', 'no se aceptan mascotas', '', 'no se permiten parejas', '', 'no se permite fumar']}
# {'title': 'habitación individual en avinguda meridiana 294', 'price': '450 €', 'address': 'avda. meridiana núm. 294,                                                                                                                             la sagrera,                                                                                                                             barcelona capital', 'lat': '41.422226 ', 'lon': '2.187218', 'description': 'preciosa habitación luz natural.al lado de todos los servicios y metro l1, l5, l9, l10, renfe.piso muy tranquilo', 'room_info': ['', 'individual', '', 'grande', '', 'exterior', '', 'amueblada'], 'flat_info': ['', '3', 'hab', '', '2', 'baños', '', '105', 'm', '', 'en buen estado', '', 'lavadora', '', 'ascensor', '', 'wifi', '', 'tv', '', 'jardín/terraza', '', 'tendedero'], 'conditions': [], 'rules': ['', 'no se aceptan mascotas', '', 'no se permiten parejas', '', 'no se permite fumar']}
# {'title': 'habitación individual en carrer del prat de la manta 11', 'price': '420 €', 'address': "c/ prat de la manta núm. 11,                                                                                                                              santa eulàlia,                                                                                                                             l'hospitalet de llobregat", 'lat': '41.361694 ', 'lon': '2.126456', 'description': 'alquilo habitacion mediana amoblada para chica sola  responsable y ordenada. 5 min de gran via 2 metro u autobuses cerca .a 15 min del aeropuerto mas info a mi contacto vivo sola con mo hija mayor buen ambiente y convivencia', 'room_info': ['', 'individual', '', 'mediana', '', 'exterior', '', 'amueblada'], 'flat_info': ['', '3', 'hab', '', '1', 'baño', '', '100', 'm', '', 'en buen estado', '', 'lavadora', '', 'wifi', '', 'jardín/terraza', '', 'tendedero'], 'conditions': [], 'rules': ['', 'no se aceptan mascotas', '', 'no se permiten parejas', '', 'no se permite fumar']}
# {'title': 'habitación doble en plaça del centre 12', 'price': '650 €', 'address': 'pza. centre núm. 12,                                                                                                                             sants,                                                                                                                             barcelona capital', 'lat': '41.38171 ', 'lon': '2.1362836', 'description': 'habitación + sala de estar/estudio totalmente privadas para el inquilino. estancia: mayo, junio y julio. (3 meses max. )piso muy luminoso, rodeado de comercio, céntrico y a 20 metros del metro plaza del centre (l3). la habitación cuenta con cama doble, zona de escritorio, sofá, mesita y armario. el apartamento cuenta con cocina completamente equipada y un baño compartido solo con 1 persona.condiciones:• un mes de fianza• tarifa plana mensual de electricidad, agua, calefacción, internet de alta velocidad· no fumador/a· no se admiten mascotas· no incluye limpieza· se exige persona limpia, tranquila y silenciosa.• consultar estancia mínima• de documentación únicamente solicitamos dni o pasaporte.condiciones:•un mes de fianza•admin fee & member live it club: 150€ (pago único)•tarifa plana mensual de electricidad, agua, calefacción, internet de alta velocidad•consultar estancia mínima•de documentación únicamente solicitamos dni o pasaporte.*(no se inlcuye ni el ordenad', 'room_info': ['', 'doble', '', 'grande', '', 'exterior', '', 'amueblada', '', 'llave propia'], 'flat_info': ['', '4', 'hab', '', '1', 'baño', '', '65', 'm', '', 'en buen estado', '', 'lavadora', '', 'ascensor', '', 'wifi', '', 'balcón', '', 'tendedero', '', 'plancha'], 'conditions': [], 'rules': ['', 'no se aceptan mascotas', '', 'no se permiten parejas', '', 'no se permite fumar']}
# {'title': "habitación individual en carrer de l'om 11", 'price': '400 €', 'address': 'c/ sebastià garriga núm. 7,                                                                                                                              serraparrera,                                                                                                                             cerdanyola del vallès', 'lat': '41.4897112 ', 'lon': '2.1313846', 'description': 'habitación en cerdanyola, a 20 min de la universidad, bus a 200m y rodalies a 20 min.cerca del centro ( día, charter,ayuntamiento, cap... )compartiríamos gastos de : agua, luz, gas, wifi y prod. limpieza comunes', 'room_info': ['', 'individual', '', 'pequeña', '', 'exterior', '', 'amueblada', '', 'llave propia'], 'flat_info': ['', '3', 'hab', '', '1', 'baño', '', '60', 'm', '', 'reformado', '', 'lavadora', '', 'ascensor', '', 'wifi', '', 'tv', '', 'balcón', '', 'tendedero'], 'conditions': [], 'rules': ['', 'no se aceptan mascotas', '', 'no se permiten parejas', '', 'no se permite fumar']}
# {'title': 'habitación en alquiler en sant miquel-tres torres', 'price': '425 €', 'address': 'c/ bartolomé esteban murillo núm. 71,                                                                                                                              sant miquel-tres torres,                                                                                                                             granollers', 'lat': '41.602203 ', 'lon': '2.2909915', 'description': 'tenemos disponible una habitación para alquilar, ideal para una mujer. está estrictamente prohibido fumar dentro del inmueble, así como la presencia de mascotas y menores de edad.los gastos asociados al uso y mantenimiento común no están incluidos en el precio del alquiler y serán repartidos proporcionalmente entre los inquilinos en función de su número actual.la habitación, amplia y repleta de luz natural, cuenta con aproximadamente 13 m² y se ubica a tan solo dos minutos de la estación de trenes. próximamente, una vez finalizados los trabajos de pintura, la habitación estará equipada con los siguientes muebles:un armario de gran capacidad.una cama doble.un colchón doble.dos mesitas de noche.se requiere una inquilina trabajadora, que posiblemente combine su actividad laboral con estudios. es imprescindible contar con un contrato de trabajo vigente o disponer de un avalista.el precio de alquiler incluido en este anuncio abarca no solo el uso de la habitación, sino también varios servicios adicionales como el alquiler de muebles, un seguro de habitabilidad, servicios de mediación para la resolución de conflictos entre inquilinos y la posibilidad de adelantar el pago de los suministros, que será regularizado el mes siguiente, entre otros.precio de referencia: 10.03 - 13.51€/m².información adicional: este inmueble se arrienda por primera vez.el propietario del inmueble no se considera un gran tenedor (posee menos de cinco propiedades).', 'room_info': ['', 'mediana', '', 'exterior'], 'flat_info': ['', '1', 'hab', '', '1', 'baño', '', '80', 'm', '', 'reformado'], 'conditions': [], 'rules': ['', 'no se aceptan mascotas', '', 'no se permiten parejas', '', 'no se permite fumar']}
# {'title': 'habitación en alquiler en ctra. de santpedor-bases de manresa', 'price': '380 €', 'address': 'avda. avinguda de les bases de manresa núm. 160,                                                                                                                              ctra. de santpedor-bases de manresa,                                                                                                                             manresa', 'lat': '41.735677975558 ', 'lon': '1.8340224074094', 'description': 'disponibilidad a partir del 1 de mayo, servicio de limpieza (zonas comunes) y wifi incluido. suministros a dividir con el resto de inquilinos.', 'room_info': ['', 'mediana', '', 'exterior'], 'flat_info': ['', '1', 'hab', '', '2', 'baños', '', '114', 'm', '', 'en buen estado'], 'conditions': [], 'rules': ['', 'no se aceptan mascotas', '', 'no se permiten parejas', '', 'no se permite fumar']}
# {'title': 'habitación individual en carrer de margarit 27', 'price': '370 €', 'address': 'c/ margarit núm. 27,                                                                                                                             el poble-sec,                                                                                                                             barcelona capital', 'lat': '41.37338 ', 'lon': '2.1635385', 'description': 'se alquila habitación cerca de plaza españa y muy cerca de la montaña de montjuic y del corazón de barcelona a pie o en transporte a 50 metros del apartamento. hay supermercados a pocos metros.  en la calle margarit y carrer blai, que son famosos por sus bares de tapas. puedes ir caminando a la rambla en 7 minutos y port vell está a 5 minutos. a 10 minutos a pie se puede llegar a plaza españa y a todas las atracciones más famosas de barcelona.estamos alquilando una habitacion individual con las comodidades necesarias  un minimo de 3 meses pero lo ideal es para un estancia larga para una chica estudiante o trabajadora,  cuesta 370 euros todo incluido, cualquier pregunta comunicarse con camila  34 611 65 41 40gracias', 'room_info': ['', 'individual', '', 'pequeña', '', 'exterior', '', 'amueblada'], 'flat_info': ['', '1', 'hab', '', '1', 'baño', '', '67', 'm', '', 'a estrenar', '', 'lavadora', '', 'ascensor', '', 'wifi', '', 'tendedero', '', 'plancha'], 'conditions': [], 'rules': ['', 'no se aceptan mascotas', '', 'no se permiten parejas', '', 'no se permite fumar']}
# {'title': 'habitación individual en carrer de les salenques 19', 'price': '380 €', 'address': "c/ salenques núm. 19,                                                                                                                              ca n'oriac,                                                                                                                             sabadell", 'lat': '41.566685 ', 'lon': '2.087586', 'description': 'solo para 1 chicadisponible para entrar ya! habitación para 1 chica estudiante o con trabajo y no fumadora. imprescindible dni o niese pide 1 mes de fianza se hace contrato  (no chicos no parejas)habitación individual con armario de dos puertas correderas, pequeño escritorio, mesita de noche y cama individual, la habitación dispone de televisión con amazon prime video, netflix,  disney plus y ventilador de techo.bonito piso reformado con suelo de parquet, baño con ducha, cocina equipada y galería con lavadora y zona para tener la ropa, piso luminoso.bien ubicado junto avenida matadepera parada de autobús, zona comercial con tiendas de todo tipo a pocos metros, estación de ferrocarril a 7 minutos caminando y renfe 15 minutos a pie.internet fibra óptica de 10 gigas simétricos y wifi 6.hacemos contrato mínimo de 6 meses y puedes empadronarte si lo necesitas.habitación con gastos incluidos en el precio luz agua gas y wifi.', 'room_info': ['', 'individual', '', 'pequeña', '', 'exterior', '', 'amueblada', '', 'llave propia'], 'flat_info': ['', '3', 'hab', '', '1', 'baño', '', '90', 'm', '', 'reformado', '', 'trastero', '', 'lavadora', '', 'wifi', '', 'tv', '', 'jardín/terraza', '', 'balcón', '', 'tendedero'], 'conditions': [], 'rules': ['', 'no se aceptan mascotas', '', 'no se permiten parejas', '', 'no se permite fumar']}
# {'title': 'habitación individual en carrer del segre 92', 'price': '350 €', 'address': 'c/ segre núm. 92,                                                                                                                             sant andreu,                                                                                                                             barcelona capital', 'lat': '41.43094 ', 'lon': '2.1945753', 'description': 'se alquila habitacion individual amueblada para una chica que trabaje y/o estudie. se requerira documentacion que lo acredite. en el precio se incluyen los suminstros siempre que no sobrepase el coste calculado. fianza de 1 mes y medio.se busca persona tranquila y respetuosa ya que se trata de una vivienda que se respira calma. el piso esta compuesto por cocina abierta con barra, baño, galeria, 4 habitaciones y no hay salon, de esta manera se crea una estancia mas tranquila. para la visita traer documentación laboral o de estudiante, o bien enviarla antes. reserva de 120e.', 'room_info': ['', 'individual', '', 'pequeña', '', 'exterior', '', 'amueblada', '', 'llave propia'], 'flat_info': ['', '4', 'hab', '', '1', 'baño', '', '55', 'm', '', 'en buen estado', '', 'lavadora', '', 'ascensor', '', 'wifi', '', 'tendedero'], 'conditions': [], 'rules': ['', 'no se aceptan mascotas', '', 'no se permiten parejas', '', 'no se permite fumar']}
# {'title': 'habitación en alquiler en can mas', 'price': '340 €', 'address': 'rbla sant jordi núm. 50,                                                                                                                              can mas,                                                                                                                             ripollet', 'lat': '41.497066 ', 'lon': '2.1607356', 'description': 'solo chicas,habitación atico con todo incluido, más terraza de 60 metros .', 'room_info': ['', 'mediana', '', 'exterior'], 'flat_info': ['', '1', 'hab', '', '1', 'baño', '', '80', 'm', '', 'en buen estado'], 'conditions': [], 'rules': ['', 'no se aceptan mascotas', '', 'no se permiten parejas', '', 'no se permite fumar']}
# {'title': 'habitación en alquiler en sant climent de llobregat', 'price': '350 €', 'address': 'cra. viladecans a sant climent de llobregat núm. 1,                                                                                                                                                                      sant climent de llobregat, barcelona', 'lat': '41.33081 ', 'lon': '2.0061357', 'description': '??????hola buenas estoy rentando una habitacion para personas responsables y trabajadoras y respetuosas limpias y ordenada preferiblemente que sea solo para chica y mujere  madre con hija y hija con madre y con niños también ??????no hombre por favor muchas gracias viladecans. si. eso mi whatsapp 612 483 952  llamar también ???????????', 'room_info': ['', 'mediana', '', 'exterior'], 'flat_info': ['', '1', 'hab', '', '1', 'baño', '', '200', 'm', '', 'a estrenar'], 'conditions': [], 'rules': ['', 'no se aceptan mascotas', '', 'no se permiten parejas', '', 'no se permite fumar']}
# {'title': 'habitación en alquiler en vacarisses', 'price': '400 €', 'address': 'c/ alzina del boixadell núm. 55,                                                                                                                                                                      vacarisses, barcelona', 'lat': '41.587738 ', 'lon': '1.9241105', 'description': 'habitacion en alquiler en chalet con jardín ,piscina ,vistas…a 5 minutos de transporte público,buena ubicación cerca de terrassa ,gastos incluidos', 'room_info': ['', 'mediana', '', 'exterior'], 'flat_info': ['', '1', 'hab', '', '2', 'baños', '', '150', 'm', '', 'en buen estado'], 'conditions': [], 'rules': ['', 'no se aceptan mascotas', '', 'no se permiten parejas', '', 'no se permite fumar']}
# {'title': 'habitación en alquiler en vallpineda-rocamar', 'price': '695 €', 'address': 'c/ mercè amell núm. 5,                                                                                                                              vallpineda-rocamar,                                                                                                                             sant pere de ribes', 'lat': '41.246075 ', 'lon': '1.7911419', 'description': 'una amplia habitación con vistas a la montaña, separada de la casa, con baño propio y amplia terraza de uso exclusivo. además de una nevera y cocina de gas también de uso exclusivo.', 'room_info': ['', 'mediana', '', 'exterior'], 'flat_info': ['', '1', 'hab', '', '2', 'baños', '', '120', 'm', '', 'en buen estado'], 'conditions': [], 'rules': ['', 'no se aceptan mascotas', '', 'no se permiten parejas', '', 'no se permite fumar']}
# {'title': 'habitación doble en piso compartido con gastos incluidos', 'price': '600 €', 'address': 'c/ junta comerç núm. 13,                                                                                                                             el raval,                                                                                                                             barcelona capital', 'lat': '41.3799636 ', 'lon': '2.1714995', 'description': 'habitación doble con dos camas individuales de 90x200m, escritorio, armario. ventana exterior.', 'room_info': ['', 'doble', '', 'mediana', '', 'exterior', '', 'amueblada', '', 'llave propia', '', 'balcón propio'], 'flat_info': ['', '8', 'hab', '', '4', 'baños', '', '200', 'm', '', 'en buen estado', '', 'lavadora', '', 'calefacción', '', 'wifi', '', 'tv', '', 'balcón', '', 'tendedero', '', 'plancha', '', 'secadora'], 'conditions': [], 'rules': ['', 'no se aceptan mascotas', '', 'se permiten parejas', '', 'no se permite fumar']}
# {'title': 'habitación en alquiler en bonavista-bufalà', 'price': '600 €', 'address': 'c/ doctor robert núm. 226,                                                                                                                              bonavista-bufalà,                                                                                                                             badalona', 'lat': '41.46345 ', 'lon': '2.2404253', 'description': 'estudio con entrada independiente ideal para un estudiante a 5 minutos del hospital de can ruti en muy buena zona , equipado de todo (es para una persona) con gatos incluidos más información por privado', 'room_info': ['', 'mediana', '', 'exterior'], 'flat_info': ['', '1', 'hab', '', '1', 'baño', '', '25', 'm', '', 'a estrenar'], 'conditions': [], 'rules': ['', 'no se aceptan mascotas', '', 'no se permiten parejas', '', 'no se permite fumar']}
# {'title': 'habitación en alquiler en olesa de montserrat', 'price': '400 €', 'address': 'olesa de montserrat, barcelona', 'lat': '41.54459353 ', 'lon': '1.895714016', 'description': 'altura piso 1º, habitación en piso superficie total 200 m², habitaciones dobles: 6, 1 baño, 1 aseo, aire acondicionado (ventilador techo), calefacción (central), cocina, estado conservación: buen estado, amueblada, número de inquilinos: 1, , exterior, se aceptan mascotas, .', 'room_info': ['', 'mediana', '', 'exterior'], 'flat_info': ['', '1', 'hab', '', '2', 'baños', '', '200', 'm', '', 'en buen estado'], 'conditions': [], 'rules': ['', 'no se aceptan mascotas', '', 'no se permiten parejas', '', 'no se permite fumar']}
# {'title': 'habitación en alquiler en matadepera', 'price': '460 €', 'address': 'c/ mas salles núm. 22,                                                                                                                                                                      matadepera, barcelona', 'lat': '41.61669 ', 'lon': '1.9988234', 'description': 'se alquila habitacion doble de 15 mts con baño privado en matadeperareformado, armario vestidor muy grande,con vistas a la montaña y mucha luz.la casa tiene jardín. gastos incluidos. se necesita coche. a 10 min de terrassa y sabadell. hay una parada de autobus a dos minutos de la casa para ir a terrassa. no se aceptan, parejas, familias ni perros. gato si, para venir a verla podeis llamar sin dudarlo 630196530/buen ambiente, amantes de la música y de la naturaleza son bienvenidos,', 'room_info': ['', 'mediana', '', 'exterior'], 'flat_info': ['', '1', 'hab', '', '4', 'baños', '', '150', 'm', '', 'reformado'], 'conditions': [], 'rules': ['', 'no se aceptan mascotas', '', 'no se permiten parejas', '', 'no se permite fumar']}
# {'title': 'habitación en alquiler en gràcia', 'price': '400 €', 'address': 'gràcia,                                                                                                                             sabadell', 'lat': '41.5359884 ', 'lon': '2.1069908', 'description': 'habitación en residencia de estudiantes con terraza, en espectacular casa con gran jardín, gran comedor-salón, wifi, calefaccion y aire acondicionado, barios baños completos uno de ellos con gran ducha, gran cocina con sala de estar.', 'room_info': ['', 'mediana', '', 'exterior'], 'flat_info': ['', '1', 'hab', '', '0', 'baños', '', '100', 'm', '', 'en buen estado'], 'conditions': [], 'rules': ['', 'no se aceptan mascotas', '', 'no se permiten parejas', '', 'no se permite fumar']}
# {'title': 'habitación en alquiler en montmeló', 'price': '340 €', 'address': 'pge. montserrat roig núm. 1,                                                                                                                                                                      montmeló, barcelona', 'lat': '41.55222 ', 'lon': '2.2466507', 'description': 'se alquila habitación individual  a chica estudiante, con derecho a cocina. se compartiría con familia de 3 miembros y un perro muy cariñoso (bicho maltes), tranquilo y respetuoso. la habitación da a un balcón soleado; tiene mucha luz durante todo el día; sin ruidos. dispone de calefacción central a gas.el ambiente en el piso es tranquilo y familiar, y está aproximadamente a 350 m de la estación de tren de renfe (líneas r2 y r8). se tarda 25 minutos  en llegar a la estación paseo de gracia y unos 18 minutos a la estación de la uab (cerdanyola). el bloque tiene altura de 2 pisos.buscamos una estudiante responsable,  respetuosa, sociable y no fumadora. el precio de la habitación es de 340€, más los gastos de agua, electricidad y gas que son a compartir.', 'room_info': ['', 'mediana', '', 'exterior'], 'flat_info': ['', '1', 'hab', '', '2', 'baños', '', '115', 'm', '', 'en buen estado'], 'conditions': [], 'rules': ['', 'no se aceptan mascotas', '', 'no se permiten parejas', '', 'no se permite fumar']}
# ...
# {'title': 'habitación individual en carrer del rosselló 213', 'price': '790 €', 'address': "c/ rossello núm. 213,                                                                                                                             la dreta de l'eixample,                                                                                                                             barcelona capital", 'lat': '41.3929735 ', 'lon': '2.1567321', 'description': 'la habitación incluye contrato legal, empadronamiento, limpieza profesional, agua, luz, gas, internet de alta velocidad y mantenimientos. soy paloma: ) y mi whatsapp es +34 722 43 94 28 si te gusta nuestra habitación escríbeme o llámame cuando quieras, estaremos encantados de darte más información.', 'room_info': ['', 'individual', '', 'grande', '', 'exterior', '', 'amueblada', '', 'llave propia', '', 'balcón propio'], 'flat_info': ['', '6', 'hab', '', '2', 'baños', '', '81', 'm', '', 'reformado', '', 'lavadora', '', 'wifi', '', 'secadora'], 'conditions': [], 'rules': ['', 'no se aceptan mascotas', '', 'no se permiten parejas', '', 'no se permite fumar']}
# {'title': 'habitación doble en carrer del rosselló 213', 'price': '950 €', 'address': "c/ rossello núm. 213,                                                                                                                             la dreta de l'eixample,                                                                                                                             barcelona capital", 'lat': '41.3929735 ', 'lon': '2.1567321', 'description': 'la habitación incluye contrato legal, empadronamiento, limpieza profesional, agua, luz, gas, internet de alta velocidad y mantenimientos. soy paloma: ) y mi whatsapp es +34 722 43 94 28 si te gusta nuestra habitación escríbeme o llámame cuando quieras, estaremos encantados de darte más información.', 'room_info': ['', 'doble', '', 'grande', '', 'exterior', '', 'amueblada', '', 'llave propia', '', 'balcón propio'], 'flat_info': ['', '1', 'hab', '', '3', 'baños', '', '81', 'm', '', 'reformado', '', 'lavadora', '', 'wifi', '', 'secadora', '', 'aire acond.'], 'conditions': [], 'rules': ['', 'no se aceptan mascotas', '', 'se permiten parejas', '', 'no se permite fumar']}
# {'title': 'habitación individual en carrer del rosselló 213', 'price': '590 €', 'address': "c/ rossello núm. 213,                                                                                                                             la dreta de l'eixample,                                                                                                                             barcelona capital", 'lat': '41.3929735 ', 'lon': '2.1567321', 'description': 'la habitación incluye contrato legal, empadronamiento, limpieza profesional, agua, luz, gas, internet de alta velocidad y mantenimientos. soy paloma: ) y mi whatsapp es +34 722 43 94 28 si te gusta nuestra habitación escríbeme o llámame cuando quieras, estaremos encantados de darte más información.', 'room_info': ['', 'individual', '', 'mediana', '', 'amueblada', '', 'llave propia'], 'flat_info': ['', '6', 'hab', '', '3', 'baños', '', '81', 'm', '', 'reformado', '', 'lavadora', '', 'wifi', '', 'secadora'], 'conditions': [], 'rules': ['', 'no se aceptan mascotas', '', 'no se permiten parejas', '', 'no se permite fumar']}
# {'title': 'habitación individual en carrer del rosselló 213', 'price': '640 €', 'address': "c/ rossello núm. 213,                                                                                                                             la dreta de l'eixample,                                                                                                                             barcelona capital", 'lat': '41.3929735 ', 'lon': '2.1567321', 'description': 'la habitación incluye contrato legal, empadronamiento, limpieza profesional, agua, luz, gas, internet de alta velocidad y mantenimientos. soy paloma: ) y mi whatsapp es +34 722 43 94 28 si te gusta nuestra habitación escríbeme o llámame cuando quieras, estaremos encantados de darte más información.', 'room_info': ['', 'individual', '', 'mediana', '', 'amueblada', '', 'llave propia'], 'flat_info': ['', '6', 'hab', '', '3', 'baños', '', '81', 'm', '', 'reformado', '', 'lavadora', '', 'wifi', '', 'secadora'], 'conditions': [], 'rules': ['', 'no se aceptan mascotas', '', 'no se permiten parejas', '', 'no se permite fumar']}
# {'title': 'habitación individual en carrer del rosselló 213', 'price': '640 €', 'address': "c/ rossello núm. 213,                                                                                                                             la dreta de l'eixample,                                                                                                                             barcelona capital", 'lat': '41.3929735 ', 'lon': '2.1567321', 'description': 'la habitación incluye contrato legal, empadronamiento, limpieza profesional, agua, luz, gas, internet de alta velocidad y mantenimientos. soy paloma: ) y mi whatsapp es +34 722 43 94 28 si te gusta nuestra habitación escríbeme o llámame cuando quieras, estaremos encantados de darte más información.', 'room_info': ['', 'individual', '', 'mediana', '', 'exterior', '', 'amueblada', '', 'llave propia'], 'flat_info': ['', '6', 'hab', '', '3', 'baños', '', '81', 'm', '', 'reformado', '', 'lavadora', '', 'wifi', '', 'secadora'], 'conditions': [], 'rules': ['', 'no se aceptan mascotas', '', 'no se permiten parejas', '', 'no se permite fumar']}
# {'title': 'habitación individual en carrer del rosselló 213', 'price': '640 €', 'address': "c/ rossello núm. 213,                                                                                                                             la dreta de l'eixample,                                                                                                                             barcelona capital", 'lat': '41.3929735 ', 'lon': '2.1567321', 'description': 'la habitación incluye contrato legal, empadronamiento, limpieza profesional, agua, luz, gas, internet de alta velocidad y mantenimientos. soy paloma: ) y mi whatsapp es +34 722 43 94 28 si te gusta nuestra habitación escríbeme o llámame cuando quieras, estaremos encantados de darte más información.', 'room_info': ['', 'individual', '', 'mediana', '', 'exterior', '', 'amueblada', '', 'llave propia'], 'flat_info': ['', '6', 'hab', '', '3', 'baños', '', '81', 'm', '', 'reformado', '', 'lavadora', '', 'wifi', '', 'secadora'], 'conditions': [], 'rules': ['', 'no se aceptan mascotas', '', 'no se permiten parejas', '', 'no se permite fumar']}
# {'title': 'habitación individual en ronda de sant pere 12', 'price': '790 €', 'address': 'c/ ronda sant pere núm. 12,                                                                                                                             el barri gòtic,                                                                                                                             barcelona capital', 'lat': '41.3883163 ', 'lon': '2.1717292', 'description': 'the apartment and the rooms are totally designed and furnished with style by our team of interior designers. we only accept mid-long term stays for students and young professionals for home use. under any circumstances we do not take tourist stays. the tenant must pay directly with the property manager at the latest within 48 hours immediately after the reservation is confirmed a deposit of € 1,000 that will be returned at the end of their contract, deducting €300 as a non-returnable service fee. the tenant must sign up the contract at the latest within 48 hours immediately after the deposit has been paid. maximum contract length is 6 months, extensible as many times as you wish. each extension admin fee is €60. you can get your “empadronamiento” at this property.', 'room_info': ['', 'individual', '', 'grande', '', 'amueblada', '', 'llave propia'], 'flat_info': ['', '5', 'hab', '', '2', 'baños', '', '102', 'm', '', 'reformado', '', 'lavadora', '', 'wifi', '', 'tv'], 'conditions': [], 'rules': ['', 'no se aceptan mascotas', '', 'no se permiten parejas', '', 'no se permite fumar']}
# {'title': 'rh23-r3 nice and cozy room in bcn', 'price': '790 €', 'address': 'c/ ronda sant pere núm. 12,                                                                                                                             el barri gòtic,                                                                                                                             barcelona capital', 'lat': '41.3883163 ', 'lon': '2.1717292', 'description': 'the apartment and the rooms are totally designed and furnished with style by our team of interior designers. we only accept mid-long term stays for students and young professionals for home use. under any circumstances we do not take tourist stays. the tenant must pay directly with the property manager at the latest within 48 hours immediately after the reservation is confirmed a deposit of € 1,000 that will be returned at the end of their contract, deducting €300 as a non-returnable service fee. the tenant must sign up the contract at the latest within 48 hours immediately after the deposit has been paid. maximum contract length is 6 months, extensible as many times as you wish. each extension admin fee is €60. you can get your “empadronamiento” at this property.', 'room_info': ['', 'doble', '', 'grande', '', 'amueblada', '', 'llave propia'], 'flat_info': ['', '5', 'hab', '', '2', 'baños', '', '102', 'm', '', 'reformado', '', 'lavadora', '', 'wifi', '', 'tv'], 'conditions': [], 'rules': ['', 'no se aceptan mascotas', '', 'no se permiten parejas', '', 'no se permite fumar']}
# {'title': 'habitación individual en ronda de sant pere 12', 'price': '790 €', 'address': 'c/ ronda sant pere núm. 12,                                                                                                                             el barri gòtic,                                                                                                                             barcelona capital', 'lat': '41.3883163 ', 'lon': '2.1717292', 'description': 'the apartment and the rooms are totally designed and furnished with style by our team of interior designers. we only accept mid-long term stays for students and young professionals for home use. under any circumstances we do not take tourist stays. the tenant must pay directly with the property manager at the latest within 48 hours immediately after the reservation is confirmed a deposit of € 1,000 that will be returned at the end of their contract, deducting €300 as a non-returnable service fee. the tenant must sign up the contract at the latest within 48 hours immediately after the deposit has been paid. maximum contract length is 6 months, extensible as many times as you wish. each extension admin fee is €60. you can get your “empadronamiento” at this property.', 'room_info': ['', 'individual', '', 'grande', '', 'amueblada', '', 'llave propia'], 'flat_info': ['', '5', 'hab', '', '2', 'baños', '', '102', 'm', '', 'reformado', '', 'lavadora', '', 'wifi', '', 'tv'], 'conditions': [], 'rules': ['', 'no se aceptan mascotas', '', 'no se permiten parejas', '', 'no se permite fumar']}
# {'title': 'habitación doble en ronda de sant pere 12', 'price': '950 €', 'address': 'c/ rond sant pere núm. 12,                                                                                                                             el barri gòtic,                                                                                                                             barcelona capital', 'lat': '41.3883163 ', 'lon': '2.1717292', 'description': 'the apartment and the rooms are totally designed and furnished with style by our team of interior designers. we only accept mid-long term stays for students and young professionals for home use. under any circumstances we do not take tourist stays. the tenant must pay directly with the property manager at the latest within 48 hours immediately after the reservation is confirmed a deposit of € 1,000 that will be returned at the end of their contract, deducting €300 as a non-returnable service fee. the tenant must sign up the contract at the latest within 48 hours immediately after the deposit has been paid. maximum contract length is 6 months, extensible as many times as you wish. each extension admin fee is €60. if this room is suitable for couples, the applicable monthly rent for couples is € 950. you can get your “empadronamiento” at this property.', 'room_info': ['', 'doble', '', 'grande', '', 'exterior', '', 'amueblada', '', 'llave propia'], 'flat_info': ['', '5', 'hab', '', '2', 'baños', '', '102', 'm', '', 'reformado', '', 'lavadora', '', 'wifi', '', 'tv', '', 'balcón', '', 'aire acond.'], 'conditions': [], 'rules': ['', 'no se aceptan mascotas', '', 'se permiten parejas', '', 'no se permite fumar']}
# {'title': 'habitación doble en ronda de sant pere 12', 'price': '850 €', 'address': 'c/ ronda sant pere núm. 12,                                                                                                                             el barri gòtic,                                                                                                                             barcelona capital', 'lat': '41.3883163 ', 'lon': '2.1717292', 'description': 'the apartment and the rooms are totally designed and furnished with style by our team of interior designers. we only accept mid-long term stays for students and young professionals for home use. under any circumstances we do not take tourist stays. the tenant must pay directly with the property manager at the latest within 48 hours immediately after the reservation is confirmed a deposit of € 1,000 that will be returned at the end of their contract, deducting €300 as a non-returnable service fee. the tenant must sign up the contract at the latest within 48 hours immediately after the deposit has been paid. maximum contract length is 6 months, extensible as many times as you wish. each extension admin fee is €60. you can get your “empadronamiento” at this property.', 'room_info': ['', 'doble', '', 'grande', '', 'amueblada', '', 'llave propia'], 'flat_info': ['', '5', 'hab', '', '2', 'baños', '', '102', 'm', '', 'reformado', '', 'lavadora', '', 'wifi', '', 'tv'], 'conditions': [], 'rules': ['', 'no se aceptan mascotas', '', 'no se permiten parejas', '', 'no se permite fumar']}
# {'title': 'habitación individual en carrer de roger de llúria 145', 'price': '850 €', 'address': "c/ roger de llúria núm. 147,                                                                                                                             la dreta de l'eixample,                                                                                                                             barcelona capital", 'lat': '41.397921 ', 'lon': '2.1623428', 'description': 'la habitación incluye contrato legal, empadronamiento, limpieza profesional, agua, luz, gas, internet de alta velocidad y mantenimientos. soy paloma :) y mi whatsapp es +34 722 43 94 28, si te gusta nuestra habitación escríbeme o llámame cuando quieras a mi o a mi compi eva, estaremos encantados de darte más información y enseñártela presencialmente si lo deseas. aquí te dejo también el teléfono y whatsapp de mi compi eva: +34 693 80 15 91.  ¿buscas una habitación bonita y de diseño en barcelona? vente a vivir con nosotros', 'room_info': ['', 'individual', '', 'mediana', '', 'exterior', '', 'amueblada'], 'flat_info': ['', '10', 'hab', '', '5', 'baños', '', '460', 'm', '', 'reformado', '', 'lavadora', '', 'ascensor', '', 'wifi', '', 'tv', '', 'jardín/terraza', '', 'tendedero', '', 'secadora'], 'conditions': [], 'rules': ['', 'no se aceptan mascotas', '', 'no se permiten parejas', '', 'no se permite fumar']}

# %% [markdown]
# # Structuring data

# %% [markdown]
# ## Room info
#
# Next steps will check what unique items room_info holds to provide info.

# %%
# Checking raw info given in room_info
room_info_items = []
for data in clean_data:
    for item in data['room_info']:
        if item not in room_info_items and item != '':
            room_info_items.append(item)

# %%
for i, v in enumerate(room_info_items):
    print(i, v)
# Out:
# 0 mediana
# 1 exterior
# 2 amueblada
# 3 individual
# 4 grande
# 5 doble
# 6 llave propia
# 7 balcón propio
# 8 pequeña
# 9 baño propio
# 10 interior y exterior adaptados
# 11 exterior adaptado
# 12 interior adaptado

# %% [markdown]
# ## What whas seen in raw data for room info:
#
# 1) Room size
# 2) Room location: internal or external
# 3) Furnished
# 4) Indivual or doubled
# 5) Personal key
# 6) private bathroom
# 7) private balcony

# %%
# Asking question to raw data


for data in clean_data:
    #print(data['room_info'])
    # Room size?
    data['room_size'] = room_size(data)

    # Furnished?
    data['furnished'] = furnished(data)

    # Private bathroom?
    data['private_bathroom'] = private_bathroom(data)

    # Individual or double?
    data['individual_or_double'] = individual_or_double(data)
    
    # Room position
    data['room_position'] = room_position(data)

# %% [markdown]
# ## Flat info
#
# As before, same process will be done for flat info

# %%
# Checking flat info unique values
flat_info_items = []
for data in clean_data:
    for item in data['flat_info']:
        if item not in flat_info_items and item != '':
            flat_info_items.append(item)

# %%
for i, v in enumerate(flat_info_items):
    print(i, v)
# Out:
# 0 1
# 1 hab
# 2 baño
# 3 32
# 4 m
# 5 en buen estado
# 6 90
# 7 60
# 8 reformado
# 9 2
# 10 baños
# 11 120
# 12 104
# 13 8
# 14 0
# 15 80
# 16 10
# 17 4
# 18 95
# 19 lavadora
# 20 ascensor
# 21 wifi
# 22 tv
# 23 tendedero
# 24 plancha
# 25 3
# 26 54
# 27 75
# 28 balcón
# 29 85
# 30 77
# 31 aire acond.
# 32 jardín/terraza
# 33 100
# 34 trastero
# 35 200
# 36 piscina propia
# 37 secadora
# 38 65
# 39 105
# 40 114
# 41 67
# 42 a estrenar
# 43 55
# 44 150
# 45 calefacción
# 46 25
# 47 115
# 48 110
# 49 63
# 50 70
# 51 107
# 52 78
# 53 130
# 54 15
# 55 56
# 56 79
# 57 82
# 58 piscina comunitaria
# 59 87
# 60 109
# 61 9
# 62 5
# 63 145
# 64 6
# 65 180
# 66 68
# 67 140
# 68 66
# 69 125
# 70 40
# 71 88
# 72 155
# 73 50
# 74 74
# 75 73
# 76 230
# 77 12
# 78 127
# 79 175
# 80 225
# 81 52
# 82 7
# 83 98
# 84 160
# 85 93
# 86 92
# 87 83
# 88 64
# 89 270
# 90 300
# 91 315
# 92 30
# 93 164
# 94 135
# 95 165
# 96 11
# 97 76
# 98 400
# 99 72
# 100 42
# 101 179
# 102 a reformar
# 103 18
# 104 53
# 105 170
# 106 89
# 107 136
# 108 112
# 109 250
# 110 118
# 111 500
# 112 260
# 113 240
# 114 220
# 115 190
# 116 84
# 117 47
# 118 91
# 119 275
# 120 16
# 121 22
# 122 20
# 123 460
# 124 119
# 125 187
# 126 226
# 127 117
# 128 142
# 129 35
# 130 206
# 131 133
# 132 14
# 133 129
# 134 168
# 135 102
# 136 94
# 137 124
# 138 97
# 139 81

# %% [markdown]
# ## What was seen in raw data for flat info
#
# 1) Flat size
# 2) Numeber of bathrooms
# 3) Rooms aviable
# 4) Flat conditions
# 5) Wifi
# 6) Washermachine
# 7) Dryer
# 8) Pool
# 9) Heater
# 10) iron
# 11) A/C
# 12) yard/rooftop
# 13) Elevator
# 14) TV
# 15) Storage

# %%
# Asking question to raw data for flat info

for data in clean_data:
    
    # Rooms availables
    data['rooms_available'] = rooms_available(data)

    # Flat size
    data['flat_size'] = flat_size(data)

    # Bathrooms
    data['number_of_bathrooms'] = number_of_bathrooms(data)

    # Elevator
    data['elevator'] = elevator(data)

    # Pool
    data['pool'] = pool(data)

    # Terrace
    data['terrace'] = terrace(data)

    # Washer machine
    data['washer_machine'] = washer_machine(data)

    # Dryer machine
    data['dryer_machine'] = dryer_machine(data)

    # Air conditioning
    data['air_conditioning'] = air_conditioning(data)

    # Heating
    data['heating'] = heating(data)

    # Internet
    data['internet'] = internet(data)

    # TV
    data['tv'] = tv(data)

    # Storage
    data['storage'] = storage(data)

    # Flat condition
    data['flat_condition'] = flat_condition(data)

# %% [markdown]
# ## Rules info
#
# In this section rules will be checked and the options will be:
# True: Accepted
# False: Not accepted
# None: Not specified

# %%
# Getting all unique rules
rules = []
for data in clean_data:
    for rule in data['rules']:
        if rule not in rules and rule != '':
            rules.append(rule)

# %%
for i, v in enumerate(rules):
    print(i, v)
# Out:
# 0 no se aceptan mascotas
# 1 no se permiten parejas
# 2 no se permite fumar
# 3 se aceptan mascotas
# 4 se permiten parejas
# 5 se permite fumar

# %% [markdown]
# ## What rules users specify to rent:
#
# 1) Pets
# 2) Couples acceptance
# 3) Smoking

# %%
# Asking question to raw data for rules

for data in clean_data:
    
    # Are pets allowed?
    data['pets_allowed'] = pets_allowed(data)

    # Are couples allowed?
    data['couples_allowed'] = couples_allowed(data)

    # Is smoking allowed?
    data['smoking_allowed'] = smoking_allowed(data)

# %% [markdown]
# ## Cleaning last items
#
# Here items used and not necesary any more are removed to generate a single and clean table

# %%
data = pd.DataFrame(clean_data).drop(columns=['room_info', 'flat_info', 'rules'])

# %%
# Adding some useful information to track the original data
data['original_file'] = file
data['date'] = file.split('_')[-2].replace('.json', '')

# %%
# Saving data as csv in processed folder
data.to_csv(f'include/pisocompartido/processed/{file.split(".")[0]}.csv', index=False)
